# %%
import torch
from config import get_model_config, get_trainer_config
from model.utils import load_openai_weights, set_seed
from model.transformer_model import TransformerModel
import random
from model.trainer import Trainer
from model.text import BPEVocab
from model.dataset import FacebookDataset

model_config = get_model_config()
trainer_config = get_trainer_config()

set_seed(trainer_config.seed)
device = torch.device(trainer_config.device)

vocab = BPEVocab.from_files(model_config.bpe_vocab_path, model_config.bpe_codes_path)

transformer = TransformerModel(n_layers=model_config.n_layers,
                               n_embeddings=len(vocab),
                               n_pos_embeddings=model_config.n_pos_embeddings,
                               embeddings_size=model_config.embeddings_size,
                               padding_idx=vocab.pad_id,
                               n_heads=model_config.n_heads,
                               dropout=model_config.dropout,
                               embed_dropout=model_config.embed_dropout,
                               attn_dropout=model_config.attn_dropout,
                               ff_dropout=model_config.ff_dropout,
                               bos_id=vocab.bos_id,
                               eos_id=vocab.eos_id,
                               max_seq_len=model_config.max_seq_len,
                               beam_size=model_config.beam_size,  
                               length_penalty=model_config.length_penalty,
                               n_segments=model_config.n_segments,
                               annealing_topk=model_config.annealing_topk,
                               annealing=model_config.annealing,
                               diversity_coef=model_config.diversity_coef,
                               diversity_groups=model_config.diversity_groups)

train_dataset = FacebookDataset(trainer_config.train_datasets, vocab, transformer.n_pos_embeddings - 1)
test_dataset = FacebookDataset(trainer_config.test_datasets, vocab, transformer.n_pos_embeddings - 1)

model_trainer = Trainer(transformer,
                        train_dataset, 
                        test_dataset, 
                        batch_size=trainer_config.batch_size,
                        batch_split=trainer_config.batch_split, 
                        lr=trainer_config.lr, 
                        lr_warmup=trainer_config.lr_warmup, 
                        lm_weight=trainer_config.lm_weight,
                        risk_weight=trainer_config.risk_weight, 
                        n_jobs=trainer_config.n_jobs, 
                        clip_grad=trainer_config.clip_grad, 
                        device=device,
                        ignore_idxs=vocab.special_tokens_ids)

ckpt = trainer_config.default_checkpoint_path
state_dict = torch.load(ckpt, map_location=device)
model_trainer.load_state_dict(state_dict)
print('Weights loaded from {}'.format(ckpt))
# Out:
# /home/kdgyun425/.local/lib/python3.5/site-packages/torch/nn/_reduction.py:46: UserWarning: size_average and reduce args will be deprecated, please use reduction='mean' instead.
#   warnings.warn(warning.format(ret))
# Weights loaded from /data/kdgyun425/transformer/checkpoints/default_checkpoint

# %%
def sample_text_func(epoch):
    n_samples = 10
    samples_idxs = random.sample(range(len(test_dataset)), n_samples)
    samples = [test_dataset[idx] for idx in samples_idxs]
    for persona_info, dialog, target in samples:
        contexts = [torch.tensor([c], dtype=torch.long, device=model_trainer.device) for c in [persona_info, dialog] if len(c) > 0]
        prediction = model_trainer.model.predict(contexts)[0]

        persona_info_str = vocab.ids2string(persona_info[1:-1])
        dialog_str = vocab.ids2string(dialog)
        dialog_str = dialog_str.replace(vocab.talker1_bos, '\n\t- ').replace(vocab.talker2_bos, '\n\t- ')
        dialog_str = dialog_str.replace(vocab.talker1_eos, '').replace(vocab.talker2_eos, '')
        target_str = vocab.ids2string(target[1:-1])
        prediction_str = vocab.ids2string(prediction)

        print('\n')
        print('Persona info:\n\t{}'.format(persona_info_str))
        print('Dialog:{}'.format(dialog_str))
        print('Target:\n\t{}'.format(target_str))
        print('Prediction:\n\t{}'.format(prediction_str))
        
sample_text_func(100)
# Out:
# Persona info:
# 	i 'm partly deaf . i love to drink fancy tea . i am a museum tour guide . i have a big library at home .
# Dialog:
# 	- soon i will be a nurse but now i 'm barmaid . crystal here .
# 	- my name is rose and i grow them in my garden
# 	- great ! do you have blue eyes and live with your best friend ? i do .
# Target:
# 	no i am deaf partly and i live in my home alone
# Prediction:
# 	no i do not have any
#
#
# Persona info:
# 	i enjoy buying new novels . i 'm a married woman . i enjoy educational films . i am having a baby and i have never given birth before . i just became an assistant last quarter .
# Dialog:
# 	- hello how are you today ?
# 	- so tired . just laying on the couch reading my weekly book . you ?
# 	- i 'm getting ready to go to a weekend concert to hear country music .
# 	- that sounds fun . i wonder if i could do that while pregnant ?
# 	- yes you can go to a concert . just be careful . do you like country music .
# 	- i like some of it . it is popular here in pennsylvania .
# 	- cool ! my dogs also like country music . we dance when it is played .
# 	- do you like movies ? i live documentaries .
# 	- i watch the history channel quite a bit actually .
# 	- do you work at all ? i have been working a pa job a few months .
# 	- i work and have all of my fun on the weekends !
# Target:
# 	that sounds great ! my weekly goal of reading a new book keeps me busy .
# Prediction:
# 	do you have any hobbies ?
#
#
# Persona info:
# 	i ride the bus to school . i am on the soccer team . i am 13 years old . my brother is older than me .
# Dialog:
# 	- hey there , how are you ?
# Target:
# 	hi , i 'm am very good
# Prediction:
# 	i 'm good . how are you ?
#
#
# Persona info:
# 	i 'm interested in photography and like taking pictures . i am fluent in english spanish and french . i 'm an elementary school teacher . my favorite colors are red and silver . my boyfriend and i are moving into an apartment together next week .
# Dialog:
# 	- hello ! are you interested in adopting a rescued bunny ?
# 	- i love bunnies but i 'm busy moving into a new apartment with my boyfriend
# 	- i 'd have loved to live with my girlfriend before i went into the navy
# 	- the navy sounds tough . i teach elementary school .
# 	- i only joined because i love the color . i much prefer working with the bunny rescue , now .
# 	- i would like to take pictures of the bunnies . do you help alot of rabbits ?
# 	- yes , by volunteering and donating to them each month . what do take pictures of ?
# 	- i just enjoy photography and the colors red and silver .
# 	- i 've a silver eared bunny you would love , with a red , white , and navy blue bow .
# 	- your bunny sounds adorable . bunnies are very gentle and quiet animals
# 	- definitely welcomed after my years in war zones . is this your first apartment with your boyfriend ?
# Target:
# 	yes i am excited about the move . thank you for your service
# Prediction:
# 	yes it is . i live in the united states
#
#
# Persona info:
# 	i enjoy marvel story lines . i like trying new recipes and being in the ocean .
# Dialog:
# 	- hi how are you this evening ?
# 	- great ! i 'm larry here . a chef 80 of the time . . . on my pontoon 20
# 	- nice ! do you like german shepards ? i do , mine is named barnaby
# 	- great dog . i 'm into comic books , but love dogs big dogs !
# 	- comic are cool . i am scared of insects especially scorpions
# 	- are you afraid of spiders then ? spiderman is my fav comic book
# 	- yes terrified ! what is your favorite color ? mine is gray .
# Target:
# 	i guess blue , the color of crystal clear water on the lake
# Prediction:
# 	mine is blue . what is yours ?
#
#
# Persona info:
# 	i work for the military . i reside in the far north of america .
# Dialog:
# 	- hello how are you today ?
# 	- not to bad , what about you
# 	- i 'm feeling like 100 bucks
# 	- good stuff , what you do for living
# 	- i work at a museum as a guide
# 	- cool , i 'm in the army
# 	- i lost my hearing in the army . or at least part of it
# 	- wow , well thank for serving soldier
# 	- i 'm now peacefully growing my garden
# 	- i 'm from canada , where do you live
# 	- i 'm from boston baby
# Target:
# 	okay , go boston haha , fav food ?
# Prediction:
# 	cool , i live in the states
#
#
# Persona info:
# 	i did n't have a tv growing up . i might be young but i can lift very heavy weights . i enjoy alcohol and being in nature . i think i 'm immortal sometimes .
# Dialog:
# 	- how are you doing today
# 	- i 'm doing great . how are you ?
# 	- i 'm okay . wife took the credit card again
# 	- i have been married for 50 years , and mine wo n't take the card
# 	- you are so very lucky
# 	- i am . i feel like i may live forever .
# 	- why do you think that
# 	- i have aged well . i love wine . i love dancing in the moonlight .
# 	- does your wife like that too
# Target:
# 	yes we are old enough to remember when there were no tvs
# Prediction:
# 	yes , it is very relaxing . what do you like to do ?
#
#
# Persona info:
# 	mickey mouse is my favorite character . i love to sing songs from the movie frozen . i 'm in the third grade . i love to go to disney world every year .
# Dialog:
# 	- hello . how are you today ?
# 	- hi ! my name is sophie . i 'm doing well . how are you ?
# 	- very well thank you . do you have any hobbies ?
# 	- i love watching the movie frozen and singing along !
# 	- i try different coffees , read poetry and watch star wars . i have not seen frozen .
# 	- i just started the third grade and love to write poetry ! i write about mickey mouse .
# 	- that sounds like fun ! i love mickey mouse ! he 's pretty cool .
# Target:
# 	my family and i go to disney world every year ! have you ever been ?
# Prediction:
# 	i love him too ! he is my favorite .
#
#
# Persona info:
# 	i have brown curly hair . i am a vegan .
# Dialog:
# 	- hi how are you , i 'm from a small area , where are you from ?
# 	- hi there i 'm from america but my family moved down to south america
# 	- cool , i lives in america all my life , i live in a small town
# Target:
# 	i used to live in minnesota
# Prediction:
# 	that is cool do you have any pets
#
#
# Persona info:
# 	i like to meditate with art . i 've a pet canine that looks like a police canine .
# Dialog:
# 	- hello i am a country guy who wants to move to the city
# 	- hi country guy , my husband and i live in the country too
# 	- born and raised on a farm with horses
# 	- cool . no horses here , just a german shepherd
# 	- my family has generations of experience in the horse business
# 	- ok . do you have any hobbies ?
# 	- i am busy in college studying law
# 	- that 's quite to hobby . i like nhl and those adult coloring books .
# 	- adult coloring books are all the rage
# 	- they sure are . i even have one with horses .
# 	- well i might have to check that one out .
# 	- sure . i can not really say the same about law school
# 	- i hope it pays off in the long run
# Target:
# 	me too . i 'll be nice to know an attorney .
# Prediction:
# 	i hope so too . what do you do for fun ?
